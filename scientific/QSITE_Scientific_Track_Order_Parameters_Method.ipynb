# %%
import numpy as np
import pennylane as qml
import scipy.linalg

def build_annni_hamiltonian(n_qubits, kappa, h, j1=1.0, periodic=True):
    """Constructs the 1D ANNNI Hamiltonian as a PennyLane operator."""
    coeffs = []
    obs = []

    # Nearest-neighbor ZZ (ferromagnetic)
    for i in range(n_qubits - 1 + int(periodic)):
        coeffs.append(-j1)
        obs.append(qml.Z(i % n_qubits) @ qml.Z((i + 1) % n_qubits))

    # Next-nearest-neighbor ZZ (frustrating)
    for i in range(n_qubits - 2 + 2 * int(periodic)):
        coeffs.append(j1 * kappa)
        obs.append(qml.Z(i % n_qubits) @ qml.Z((i + 2) % n_qubits))

    # Transverse field X
    for i in range(n_qubits):
        coeffs.append(-h)
        obs.append(qml.X(i))

    return qml.dot(coeffs, obs)

def compute_order_parameters(psi, n_qubits):
    """Calculates C1 (nearest-neighbor) and C2 (next-nearest-neighbor) correlations."""
    c1_sum, c2_sum = 0.0, 0.0
    wires = list(range(n_qubits))

    for i in range(n_qubits):
        # Expand operators to the full Hilbert space
        z1_mat = qml.matrix(
            qml.Z(i) @ qml.Z((i + 1) % n_qubits),
            wire_order=wires
        )
        z2_mat = qml.matrix(
            qml.Z(i) @ qml.Z((i + 2) % n_qubits),
            wire_order=wires
        )
        c1_sum += np.vdot(psi, z1_mat @ psi).real
        c2_sum += np.vdot(psi, z2_mat @ psi).real

    return c1_sum / n_qubits, c2_sum / n_qubits

if __name__ == "__main__":
    # Test Parameters
    n_qubits = 8
    kappa_test = 0.2
    h_test = 0.3

    print(f"Building Hamiltonian for N={n_qubits}, kappa={kappa_test}, h={h_test}...")
    H = build_annni_hamiltonian(n_qubits, kappa=kappa_test, h=h_test)

    print("Diagonalizing Hamiltonian matrix...")
    H_matrix = qml.matrix(H)
    eigenvalues, eigenvectors = scipy.linalg.eigh(H_matrix)

    # First eigenvalue/eigenvector corresponds to the ground state
    ground_energy = eigenvalues[0]
    psi = eigenvectors[:, 0]

    # Calculate physical observables
    c1, c2 = compute_order_parameters(psi, n_qubits)

    print("\n--- Step 1 Verification Results ---")
    print(f"Ground State Energy: {ground_energy:.4f}")
    print(f"Nearest-Neighbor Correlation (C1): {c1:.4f}")
    print(f"Next-Nearest Correlation (C2): {c2:.4f}")
# Out:
# Building Hamiltonian for N=8, kappa=0.2, h=0.3...
# Diagonalizing Hamiltonian matrix...
#
# --- Step 1 Verification Results ---
# Ground State Energy: -6.6296
# Nearest-Neighbor Correlation (C1): 0.9619
# Next-Nearest Correlation (C2): 0.9596

# %%
import matplotlib.pyplot as plt
import numpy as np
import pennylane as qml
import scipy.linalg

# 1. ANNNI Hamiltonian Construction
def build_annni_hamiltonian(n_qubits, kappa, h, j1=1.0, periodic=True):
    """Constructs the 1D ANNNI Hamiltonian as a PennyLane operator."""
    coeffs = []
    obs = []

    # Nearest-neighbor ZZ (ferromagnetic)
    for i in range(n_qubits - 1 + int(periodic)):
        coeffs.append(-j1)
        obs.append(qml.Z(i % n_qubits) @ qml.Z((i + 1) % n_qubits))

    # Next-nearest-neighbor ZZ (frustrating)
    for i in range(n_qubits - 2 + 2 * int(periodic)):
        coeffs.append(j1 * kappa)
        obs.append(qml.Z(i % n_qubits) @ qml.Z((i + 2) % n_qubits))

    # Transverse field X
    for i in range(n_qubits):
        coeffs.append(-h)
        obs.append(qml.X(i))

    return qml.dot(coeffs, obs)

# 2. Physical Observables (Order Parameters)
def compute_order_parameters(psi, n_qubits):
    """Calculates C1 (nearest-neighbor) and C2 (next-nearest-neighbor) correlations."""
    c1_sum, c2_sum = 0.0, 0.0
    wires = list(range(n_qubits))

    for i in range(n_qubits):
        z1_mat = qml.matrix(qml.Z(i) @ qml.Z((i + 1) % n_qubits), wire_order=wires)
        z2_mat = qml.matrix(qml.Z(i) @ qml.Z((i + 2) % n_qubits), wire_order=wires)

        c1_sum += np.vdot(psi, z1_mat @ psi).real
        c2_sum += np.vdot(psi, z2_mat @ psi).real

    return c1_sum / n_qubits, c2_sum / n_qubits

# 3. Known Analytical Boundary Formulas for Overlay
def ising_transition(k):
    """Ising line: Ferro <-> Para for k < 0.5"""
    k = np.asarray(k, dtype=float)
    with np.errstate(divide="ignore", invalid="ignore"):
        res = (1 - k) * (1 - np.sqrt((1 - 3 * k + 4 * k**2) / (1 - k))) / np.maximum(k, 1e-9)
    return np.where(k == 0, 1.0, res)

def kt_transition(k):
    """KT line: Para <-> Antiphase for k > 0.5"""
    k = np.asarray(k, dtype=float)
    return 1.05 * np.sqrt(np.maximum(0, (k - 0.5) * (k - 0.1)))

def bkt_transition(k):
    """BKT line: Antiphase / Floating boundary for k > 0.5"""
    k = np.asarray(k, dtype=float)
    return 1.05 * np.maximum(0, k - 0.5)

if __name__ == "__main__":
    n_qubits = 8
    grid_size = 15  # 15x15 grid

    kappa_vals = np.linspace(0.0, 1.0, grid_size)
    h_vals = np.linspace(0.0, 2.0, grid_size)

    c1_grid = np.zeros((grid_size, grid_size))
    c2_grid = np.zeros((grid_size, grid_size))

    print(f"Scanning {grid_size}x{grid_size} parameter grid for N={n_qubits} qubits...")

    # Grid Sweep
    for y, h in enumerate(h_vals):
        for x, kappa in enumerate(kappa_vals):
            H = build_annni_hamiltonian(n_qubits, kappa=kappa, h=h)
            H_mat = qml.matrix(H)

            eigenvalues, eigenvectors = scipy.linalg.eigh(H_mat)
            ground_state = eigenvectors[:, 0]

            c1, c2 = compute_order_parameters(ground_state, n_qubits)
            c1_grid[y, x] = c1
            c2_grid[y, x] = c2

    print("Grid scan complete! Generating heatmaps...")

    # Plotting setup
    fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)
    k_low = np.linspace(0.0, 0.5, 100)
    k_high = np.linspace(0.5, 1.0, 100)

    # Extent boundary matches kappa_vals (0 to 1) and h_vals (0 to 2)
    plot_extent = [kappa_vals.min(), kappa_vals.max(), h_vals.min(), h_vals.max()]

    # Plot 1: Nearest-Neighbor Correlation C1
    im1 = axes[0].imshow(
        c1_grid,
        extent=plot_extent,
        origin="lower",
        aspect="auto",
        cmap="coolwarm",
    )
    axes[0].plot(k_low, ising_transition(k_low), "w--", lw=2, label="Ising Line")
    axes[0].plot(k_high, kt_transition(k_high), "w-", lw=2, label="KT Line")
    axes[0].plot(k_high, bkt_transition(k_high), "w:", lw=2, label="BKT Line")
    axes[0].set_title(r"Nearest-Neighbor Correlation $C_1 = \langle Z_i Z_{i+1} \rangle$")
    axes[0].set_xlabel(r"Frustration strength $\kappa$")
    axes[0].set_ylabel(r"Transverse field $h$")
    axes[0].legend(loc="upper right", framealpha=0.8)
    fig.colorbar(im1, ax=axes[0], label=r"$C_1$")

    # Plot 2: Next-Nearest-Neighbor Correlation C2
    im2 = axes[1].imshow(
        c2_grid,
        extent=plot_extent,
        origin="lower",
        aspect="auto",
        cmap="viridis",
    )
    axes[1].plot(k_low, ising_transition(k_low), "w--", lw=2, label="Ising Line")
    axes[1].plot(k_high, kt_transition(k_high), "w-", lw=2, label="KT Line")
    axes[1].plot(k_high, bkt_transition(k_high), "w:", lw=2, label="BKT Line")
    axes[1].set_title(r"Next-Nearest-Neighbor Correlation $C_2 = \langle Z_i Z_{i+2} \rangle$")
    axes[1].set_xlabel(r"Frustration strength $\kappa$")
    axes[1].legend(loc="upper right", framealpha=0.8)
    fig.colorbar(im2, ax=axes[1], label=r"$C_2$")

    plt.tight_layout()
    plt.savefig("clean_phase_diagram.png", dpi=300)
    plt.show()

    print("Saved clean phase diagram to 'clean_phase_diagram.png'.")
# Out:
# Scanning 15x15 parameter grid for N=8 qubits...
# Grid scan complete! Generating heatmaps...
# Saved clean phase diagram to 'clean_phase_diagram.png'.

# %%
# !pip install pennylane
import matplotlib.pyplot as plt
import numpy as np
import pennylane as qml
import scipy.linalg

# ==========================================
# 1. ANNNI Hamiltonian Construction
# ==========================================
def build_annni_hamiltonian(n_qubits, kappa, h, j1=1.0, periodic=True):
    coeffs = []
    obs = []

    # Nearest-neighbor terms
    for i in range(n_qubits - 1 + int(periodic)):
        coeffs.append(-j1)
        obs.append(qml.Z(i % n_qubits) @ qml.Z((i + 1) % n_qubits))

    # Next-nearest-neighbor terms
    for i in range(n_qubits - 2 + 2 * int(periodic)):
        coeffs.append(j1 * kappa)
        obs.append(qml.Z(i % n_qubits) @ qml.Z((i + 2) % n_qubits))

    # Transverse field terms
    for i in range(n_qubits):
        coeffs.append(-h)
        obs.append(qml.X(i))

    return qml.dot(coeffs, obs)

# ==========================================
# 2. Analytical Boundaries for Reference
# ==========================================
def ising_transition(k):
    k = np.asarray(k, dtype=float)
    with np.errstate(divide="ignore", invalid="ignore"):
        res = (1 - k) * (1 - np.sqrt((1 - 3 * k + 4 * k**2) / (1 - k))) / np.maximum(k, 1e-9)
    return np.where(k == 0, 1.0, res)

def kt_transition(k):
    k = np.asarray(k, dtype=float)
    return 1.05 * np.sqrt(np.maximum(0, (k - 0.5) * (k - 0.1)))

# ==========================================
# 3. Define Noisy Quantum Circuit
# ==========================================
n_qubits = 8
dev_mixed = qml.device("default.mixed", wires=n_qubits)

@qml.qnode(dev_mixed)
def noisy_correlation_circuit(state, p):
    # Prepare the exact ground state
    qml.StatePrep(state, wires=range(n_qubits))

    # Apply depolarizing noise across neighboring qubit interactions
    if p > 0:
        for i in range(n_qubits):
            ctrl = i
            tgt = (i + 1) % n_qubits
            qml.CNOT(wires=[ctrl, tgt])
            qml.DepolarizingChannel(p, wires=tgt)
            qml.CNOT(wires=[ctrl, tgt])
            qml.DepolarizingChannel(p, wires=tgt)

    # Return correlation expectation values
    c1_terms = [qml.expval(qml.Z(i) @ qml.Z((i + 1) % n_qubits)) for i in range(n_qubits)]
    c2_terms = [qml.expval(qml.Z(i) @ qml.Z((i + 2) % n_qubits)) for i in range(n_qubits)]
    return c1_terms, c2_terms

# ==========================================
# 4. Main Execution Grid Evaluation
# ==========================================
if __name__ == "__main__":
    grid_size = 15
    kappa_vals = np.linspace(0.0, 1.0, grid_size)
    h_vals = np.linspace(0.0, 2.0, grid_size)
    noise_levels = [0.0, 0.01, 0.05]

    # Precompute exact ground states via exact diagonalization
    print("Precomputing ground states via Exact Diagonalization...")
    ground_states = np.empty((grid_size, grid_size, 2**n_qubits), dtype=complex)
    for y, h in enumerate(h_vals):
        for x, kappa in enumerate(kappa_vals):
            H = build_annni_hamiltonian(n_qubits, kappa=kappa, h=h)
            _, eigenvectors = scipy.linalg.eigh(qml.matrix(H))
            ground_states[y, x] = eigenvectors[:, 0]

    # Set up figure
    fig, axes = plt.subplots(3, 2, figsize=(12, 14), sharex=True, sharey=True)
    k_low = np.linspace(0.0, 0.5, 100)
    k_high = np.linspace(0.5, 1.0, 100)

    # Dynamic extent map based on true values: [xmin, xmax, ymin, ymax]
    plot_extent = [kappa_vals.min(), kappa_vals.max(), h_vals.min(), h_vals.max()]

    for idx, p in enumerate(noise_levels):
        print(f"Running grid evaluation at noise level p = {p}...")
        c1_grid = np.zeros((grid_size, grid_size))
        c2_grid = np.zeros((grid_size, grid_size))

        for y in range(grid_size):
            for x in range(grid_size):
                psi = ground_states[y, x]
                c1_vals, c2_vals = noisy_correlation_circuit(psi, p)
                # Unwrap expectations from tensor structures to averages
                c1_grid[y, x] = np.mean([float(val) for val in c1_vals])
                c2_grid[y, x] = np.mean([float(val) for val in c2_vals])

        # --- Plot C1 Heatmap (Nearest-Neighbor) ---
        im1 = axes[idx, 0].imshow(
            c1_grid, extent=plot_extent, origin="lower", aspect="auto", cmap="coolwarm", vmin=-0.1, vmax=1.0
        )
        axes[idx, 0].plot(k_low, ising_transition(k_low), "w--", lw=1.5, label="Ising Transition" if idx==0 else "")
        axes[idx, 0].plot(k_high, kt_transition(k_high), "w-", lw=1.5, label="KT Transition" if idx==0 else "")
        axes[idx, 0].set_title(f"$C_1$ (Nearest-Neighbor) | Noise $p = {p}$", fontsize=11)
        axes[idx, 0].set_ylabel(r"Transverse field $h$")
        fig.colorbar(im1, ax=axes[idx, 0], fraction=0.046, pad=0.04)

        # --- Plot C2 Heatmap (Next-Nearest-Neighbor) ---
        im2 = axes[idx, 1].imshow(
            c2_grid, extent=plot_extent, origin="lower", aspect="auto", cmap="viridis", vmin=-1.0, vmax=1.0
        )
        axes[idx, 1].plot(k_low, ising_transition(k_low), "w--", lw=1.5)
        axes[idx, 1].plot(k_high, kt_transition(k_high), "w-", lw=1.5)
        axes[idx, 1].set_title(f"$C_2$ (Next-Nearest-Neighbor) | Noise $p = {p}$", fontsize=11)
        fig.colorbar(im2, ax=axes[idx, 1], fraction=0.046, pad=0.04)

    # Set bottom labels safely using exact grid axis layout dimensions
    axes[2, 0].set_xlabel(r"Frustration strength $\kappa$")
    axes[2, 1].set_xlabel(r"Frustration strength $\kappa$")

    plt.tight_layout()
    plt.savefig("noisy_phase_diagrams_comparison.png", dpi=300)
    print("Saved noisy comparison plot to 'noisy_phase_diagrams_comparison.png'")
    plt.show()
# Out:
# Collecting pennylane
#   Downloading pennylane-0.45.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from pennylane) (1.16.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.13/dist-packages (from pennylane) (3.6.1)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.18.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Collecting autograd<1.9 (from pennylane)
#   Downloading autograd-1.8.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray==0.8.4 (from pennylane)
#   Downloading autoray-0.8.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.13/dist-packages (from pennylane) (6.2.6)
# Collecting pennylane-lightning>=0.45 (from pennylane)
#   Downloading pennylane_lightning-0.45.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from pennylane) (2.32.4)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.13/dist-packages (from pennylane) (0.14.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.13/dist-packages (from pennylane) (4.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from pennylane) (26.3)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.3-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.13/dist-packages (from pennylane) (2.1.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.13/dist-packages (from pennylane) (0.7.0)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.45->pennylane)
#   Downloading scipy_openblas32-0.3.34.237.0-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: termcolor in /usr/local/lib/python3.13/dist-packages (from diastatic-malt->pennylane) (3.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->pennylane) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->pennylane) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->pennylane) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->pennylane) (2026.7.22)
# Downloading pennylane-0.45.1-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 56.8 MB/s eta 0:00:00
# Downloading autoray-0.8.4-py3-none-any.whl (937 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 937.5/937.5 kB 45.0 MB/s eta 0:00:00
# Downloading autograd-1.8.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 3.5 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.45.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (25.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 56.1 MB/s eta 0:00:00
# Downloading rustworkx-0.18.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 52.5 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.3-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.2/167.2 kB 12.8 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.34.237.0-py3-none-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 109.2 MB/s eta 0:00:00
# Installing collected packages: appdirs, scipy-openblas32, rustworkx, diastatic-malt, autoray, autograd, pennylane-lightning, pennylane
#   Attempting uninstall: autograd
#     Found existing installation: autograd 1.9.1
#     Uninstalling autograd-1.9.1:
#       Successfully uninstalled autograd-1.9.1
# Successfully installed appdirs-1.4.4 autograd-1.8.0 autoray-0.8.4 diastatic-malt-2.15.3 pennylane-0.45.1 pennylane-lightning-0.45.0 rustworkx-0.18.1 scipy-openblas32-0.3.34.237.0
# Precomputing ground states via Exact Diagonalization...
# Running grid evaluation at noise level p = 0.0...
# Running grid evaluation at noise level p = 0.01...
# Running grid evaluation at noise level p = 0.05...
# Saved noisy comparison plot to 'noisy_phase_diagrams_comparison.png'
